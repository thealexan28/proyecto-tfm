# %%
import pandas as pd

# %%
ruta_listings = '../data/madrid/listings.csv'
ruta_calendar = '../data/sevilla/calendar.csv'

# 2. Leer los archivos CSV normales
# Quitamos compression='gzip', pero mantenemos low_memory=False
df_listings = pd.read_csv(ruta_listings, low_memory=False)
df_calendar = pd.read_csv(ruta_calendar, low_memory=False)

# %%
# 3. Exploración inicial de LISTINGS (Viviendas)
print("="*50)
print(" 🏠 ANÁLISIS DE LISTINGS (Viviendas)")
print("="*50)
print(f"Total de viviendas: {df_listings.shape[0]}")
print(f"Total de columnas (variables): {df_listings.shape[1]}")
print("\nTipos de datos y valores nulos:")
df_listings.info()

# Mostrar las 5 primeras filas de listings
df_listings.head()
# Out:
# ==================================================
#  🏠 ANÁLISIS DE LISTINGS (Viviendas)
# ==================================================
# Total de viviendas: 25000
# Total de columnas (variables): 79
#
# Tipos de datos y valores nulos:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            25000 non-null  int64
#  1   listing_url                                   25000 non-null  str
#  2   scrape_id                                     25000 non-null  int64
#  3   last_scraped                                  25000 non-null  str
#  4   source                                        25000 non-null  str
#  5   name                                          25000 non-null  str
#  6   description                                   24130 non-null  str
#  7   neighborhood_overview                         10586 non-null  str
#  8   picture_url                                   24999 non-null  str
#  9   host_id                                       25000 non-null  int64
#  10  host_url                                      25000 non-null  str
#  11  host_name                                     24903 non-null  str
#  12  host_since                                    24903 non-null  str
#  13  host_location                                 16850 non-null  str
#  14  host_about                                    12598 non-null  str
#  15  host_response_time                            20115 non-null  str
#  16  host_response_rate                            20115 non-null  str
#  17  host_acceptance_rate                          20996 non-null  str
#  18  host_is_superhost                             24332 non-null  str
#  19  host_thumbnail_url                            24903 non-null  str
#  20  host_picture_url                              24903 non-null  str
#  21  host_neighbourhood                            7922 non-null   str
#  22  host_listings_count                           24903 non-null  float64
#  23  host_total_listings_count                     24903 non-null  float64
#  24  host_verifications                            24903 non-null  str
#  25  host_has_profile_pic                          24903 non-null  str
#  26  host_identity_verified                        24903 non-null  str
#  27  neighbourhood                                 10586 non-null  str
#  28  neighbourhood_cleansed                        25000 non-null  str
#  29  neighbourhood_group_cleansed                  25000 non-null  str
#  30  latitude                                      25000 non-null  float64
#  31  longitude                                     25000 non-null  float64
#  32  property_type                                 25000 non-null  str
#  33  room_type                                     25000 non-null  str
#  34  accommodates                                  25000 non-null  int64
#  35  bathrooms                                     18960 non-null  float64
#  36  bathrooms_text                                24972 non-null  str
#  37  bedrooms                                      22488 non-null  float64
#  38  beds                                          18965 non-null  float64
#  39  amenities                                     25000 non-null  str
#  40  price                                         18953 non-null  str
#  41  minimum_nights                                25000 non-null  int64
#  42  maximum_nights                                25000 non-null  int64
#  43  minimum_minimum_nights                        24988 non-null  float64
#  44  maximum_minimum_nights                        24988 non-null  float64
#  45  minimum_maximum_nights                        24988 non-null  float64
#  46  maximum_maximum_nights                        24988 non-null  float64
#  47  minimum_nights_avg_ntm                        25000 non-null  float64
#  48  maximum_nights_avg_ntm                        25000 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              23536 non-null  str
#  51  availability_30                               25000 non-null  int64
#  52  availability_60                               25000 non-null  int64
#  53  availability_90                               25000 non-null  int64
#  54  availability_365                              25000 non-null  int64
#  55  calendar_last_scraped                         25000 non-null  str
#  56  number_of_reviews                             25000 non-null  int64
#  57  number_of_reviews_ltm                         25000 non-null  int64
#  58  number_of_reviews_l30d                        25000 non-null  int64
#  59  availability_eoy                              25000 non-null  int64
#  60  number_of_reviews_ly                          25000 non-null  int64
#  61  estimated_occupancy_l365d                     25000 non-null  int64
#  62  estimated_revenue_l365d                       18953 non-null  float64
#  63  first_review                                  19853 non-null  str
#  64  last_review                                   19853 non-null  str
#  65  review_scores_rating                          19853 non-null  float64
#  66  review_scores_accuracy                        19853 non-null  float64
#  67  review_scores_cleanliness                     19852 non-null  float64
#  68  review_scores_checkin                         19852 non-null  float64
#  69  review_scores_communication                   19853 non-null  float64
#  70  review_scores_location                        19850 non-null  float64
#  71  review_scores_value                           19849 non-null  float64
#  72  license                                       9188 non-null   str
#  73  instant_bookable                              25000 non-null  str
#  74  calculated_host_listings_count                25000 non-null  int64
#  75  calculated_host_listings_count_entire_homes   25000 non-null  int64
#  76  calculated_host_listings_count_private_rooms  25000 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   25000 non-null  int64
#  78  reviews_per_month                             19853 non-null  float64
# dtypes: float64(23), int64(20), str(36)
# memory usage: 58.4 MB
#       id                         listing_url       scrape_id last_scraped  \
# 0  21853  https://www.airbnb.com/rooms/21853  20250914152907   2025-09-15
# 1  30320  https://www.airbnb.com/rooms/30320  20250914152907   2025-09-15
# 2  30959  https://www.airbnb.com/rooms/30959  20250914152907   2025-09-15
# 3  40916  https://www.airbnb.com/rooms/40916  20250914152907   2025-09-15
# 4  62423  https://www.airbnb.com/rooms/62423  20250914152907   2025-09-15
#
#             source                                          name  \
# 0  previous scrape                          Bright and airy room
# 1      city scrape                         Apartamentos Dana Sol
# 2  previous scrape               Beautiful loft in Madrid Center
# 3      city scrape                   Apartasol Apartamentos Dana
# 4      city scrape  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
#
#                                          description  \
# 0  We have a quiet and sunny room with a good vie...
# 1                                                NaN
# 2  Beautiful Loft 60m2 size just in the historica...
# 3                                                NaN
# 4  INCREDIBLE HOME OF AN ARTIST SURROUNDED BY PAI...
#
#                                neighborhood_overview  \
# 0  We live in a leafy neighbourhood with plenty o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  DISTRICT WITH VERY GOOD VIBES IN THE MIDDLE OF...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/68483181/87bc...    83531  ...
# 1  https://a0.muscache.com/pictures/336868/f67409...   130907  ...
# 2  https://a0.muscache.com/pictures/78173471/835e...   132883  ...
# 3  https://a0.muscache.com/pictures/hosting/Hosti...   130907  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   303845  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.82                   4.21                4.67
# 1                        4.78                   4.90                4.69
# 2                        4.63                   4.88                4.25
# 3                        4.81                   4.88                4.59
# 4                        4.86                   4.97                4.60
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              2
# 1     NaN                t                             17
# 2     NaN                f                              1
# 3     NaN                t                             17
# 4     NaN                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                          17
# 2                                           1
# 3                                          17
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            2
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.25
# 1                                           0              0.93
# 2                                           0              0.06
# 3                                           0              0.29
# 4                                           0              2.78
#
# [5 rows x 79 columns]

# %%
# 4. Exploración inicial de CALENDAR (Disponibilidad y precios diarios)
print("\n" + "="*50)
print(" 📅 ANÁLISIS DE CALENDAR (Disponibilidad 365 días)")
print("="*50)
print(f"Total de registros diarios: {df_calendar.shape[0]}")
print(f"Total de columnas: {df_calendar.shape[1]}")
print("\nTipos de datos y valores nulos:")
df_calendar.info()

# Mostrar las 5 primeras filas de calendar
display(df_calendar.head())
# Out:
# ==================================================
#  📅 ANÁLISIS DE CALENDAR (Disponibilidad 365 días)
# ==================================================
# Total de registros diarios: 2998475
# Total de columnas: 7
#
# Tipos de datos y valores nulos:
# <class 'pandas.DataFrame'>
# RangeIndex: 2998475 entries, 0 to 2998474
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            str
#  2   available       str
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), str(2)
# memory usage: 191.6 MB
#    listing_id        date available  price  adjusted_price  minimum_nights  \
# 0     2371981  2025-09-30         f    NaN             NaN               2
# 1     2371981  2025-10-01         f    NaN             NaN               2
# 2     2371981  2025-10-02         f    NaN             NaN               2
# 3     2371981  2025-10-03         f    NaN             NaN               2
# 4     2371981  2025-10-04         f    NaN             NaN               2
#
#    maximum_nights
# 0              20
# 1              20
# 2              20
# 3              20
# 4              20

# %%
nombre_columnas_listings = df_listings.columns.tolist()
print("\nColumnas en listings:")
for col in nombre_columnas_listings:
    print(f"- {col}")
# Out:
# Columnas en listings:
# - id
# - listing_url
# - scrape_id
# - last_scraped
# - source
# - name
# - description
# - neighborhood_overview
# - picture_url
# - host_id
# - host_url
# - host_name
# - host_since
# - host_location
# - host_about
# - host_response_time
# - host_response_rate
# - host_acceptance_rate
# - host_is_superhost
# - host_thumbnail_url
# - host_picture_url
# - host_neighbourhood
# - host_listings_count
# - host_total_listings_count
# - host_verifications
# - host_has_profile_pic
# - host_identity_verified
# - neighbourhood
# - neighbourhood_cleansed
# - neighbourhood_group_cleansed
# - latitude
# - longitude
# - property_type
# - room_type
# - accommodates
# - bathrooms
# - bathrooms_text
# - bedrooms
# - beds
# - amenities
# - price
# - minimum_nights
# - maximum_nights
# - minimum_minimum_nights
# - maximum_minimum_nights
# - minimum_maximum_nights
# - maximum_maximum_nights
# - minimum_nights_avg_ntm
# - maximum_nights_avg_ntm
# - calendar_updated
# - has_availability
# - availability_30
# - availability_60
# - availability_90
# - availability_365
# - calendar_last_scraped
# - number_of_reviews
# - number_of_reviews_ltm
# - number_of_reviews_l30d
# - availability_eoy
# - number_of_reviews_ly
# - estimated_occupancy_l365d
# - estimated_revenue_l365d
# - first_review
# - last_review
# - review_scores_rating
# - review_scores_accuracy
# - review_scores_cleanliness
# - review_scores_checkin
# - review_scores_communication
# - review_scores_location
# - review_scores_value
# - license
# - instant_bookable
# - calculated_host_listings_count
# - calculated_host_listings_count_entire_homes
# - calculated_host_listings_count_private_rooms
# - calculated_host_listings_count_shared_rooms
# - reviews_per_month
